# %%
import pandas as pd
iter_csv = pd.read_csv('./data/hmda_lar.csv', iterator=True, chunksize=10000)
df = pd.concat([chunk[chunk['state_abbr'] == "NC"] for chunk in iter_csv])

# %%
import sys
sys.getsizeof(df)
# Out:
# 1015814861

# %%
df.to_csv("./data/hmda_nc.csv")

# %%
df.head()
# Out:
#      tract_to_msamd_income  rate_spread  population  minority_population  \
# 473             162.809998          NaN     10053.0            16.190001
# 497             153.279999          NaN      4723.0            26.299999
# 539             121.639999          NaN      3764.0            15.940000
# 581             153.770004          NaN      5174.0            21.920000
# 677              98.459999          NaN      7373.0            53.220001
#
#      number_of_owner_occupied_units  number_of_1_to_4_family_units  \
# 473                          3034.0                         3595.0
# 497                          1262.0                         1614.0
# 539                           937.0                         1181.0
# 581                          1743.0                         1992.0
# 677                          1073.0                         1868.0
#
#      loan_amount_000s  hud_median_family_income  applicant_income_000s  \
# ...
