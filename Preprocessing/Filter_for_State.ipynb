# %%
import pandas as pd
iter_csv = pd.read_csv('./data/hmda_lar.csv', iterator=True, chunksize=10000)
df = pd.concat([chunk[chunk.state_abbr.isin(["NC", "VA", "GA", "SC"])] for chunk in iter_csv])

# %%
import sys
sys.getsizeof(df)
# Out:
# 3557419698

# %%
df.to_csv("./data/hmda_ncvagasc.csv")

# %%
df.head()
# Out:
#     tract_to_msamd_income  rate_spread  population  minority_population  \
# 0               63.500000          NaN      7067.0            72.080002
# 5              138.160004          NaN      7120.0            23.309999
# 11             234.160004          NaN      3298.0            22.620001
# 23             102.059998          NaN      6872.0            40.340000
# 28              88.040001          NaN      4863.0            41.950001
#
#     number_of_owner_occupied_units  number_of_1_to_4_family_units  \
# 0                           1201.0                         1303.0
# 5                           2037.0                         2431.0
# 11                          1104.0                         1175.0
# 23                          1423.0                         1971.0
# 28                           934.0                         1585.0
#
#     loan_amount_000s  hud_median_family_income  applicant_income_000s  \
# ...
